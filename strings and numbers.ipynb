# %% [markdown]
# # Basics of python programming
# This is a repo to help me go over my python and get me ready to study ML

# %%
# this is a python script that prints the Zen of Python when run
""" 
this is a triple comment
"""
# import this
# Out:
# ' \n    this is a triple comment\n'

# %% [markdown]
# code below demonstrates variables in python

# %%
seven = "wow my"
plural = "precious"
print(seven + " " + plural)
# Out:
# wow my precious

# %%
string_variable = "this is a string"
dict_variable = [1, 2, 3, 4, 5]
integer_variable = 100
float_variable = 45.234

print(type(float_variable))
print(type(integer_variable))
print(type(dict_variable))
print(type(string_variable))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
add = 70 + 400
multiply = 70 * 400
division = 340 / 123
floor_divide = 340 // 123
modular = 10 % 34
powers = 2 ** 2
print([add, multiply, division, floor_divide, modular, powers])
# Out:
# [470, 28000, 2.7642276422764227, 2, 10, 4]

# %%
stri_2 = "The future is great"
stri_2.replace(' ', '%20')
# Out:
# 'The%20future%20is%20great'
